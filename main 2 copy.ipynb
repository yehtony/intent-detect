# %%
import torch
import evaluate
import pandas as pd
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification, BertForSequenceClassification,  DataCollatorWithPadding, TrainingArguments, Trainer
# from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from datasets import Dataset, DatasetDict

# %%
data = [
    {"text": "植物", "label": 1},
    {"text": "草", "label": 1},
    {"text": "樹", "label": 1},
    {"text": "根", "label": 1},
    {"text": "莖", "label": 1},
    {"text": "葉", "label": 1},
    {"text": "花", "label": 1},
    {"text": "果實", "label": 1},
    {"text": "種子", "label": 1},
    {"text": "維管束", "label": 1},
    {"text": "木質部", "label": 1},
    {"text": "韌皮部", "label": 1},
    {"text": "葉綠體", "label": 1},
    {"text": "細胞壁", "label": 1},
    {"text": "子房", "label": 1},
    {"text": "胚珠", "label": 1},
    {"text": "胚芽", "label": 1},
    {"text": "花葯", "label": 1},
    {"text": "柱頭", "label": 1},
    {"text": "樹皮", "label": 1},
    {"text": "生長點", "label": 1},
    {"text": "蓼膜", "label": 1},
    {"text": "根毛", "label": 1},
    {"text": "帚狀根", "label": 1},
    {"text": "生長錐", "label": 1},
    {"text": "血管束", "label": 1},
    {"text": "葉柄", "label": 1},
    {"text": "根帽", "label": 1},
    {"text": "絲狀根", "label": 1},
    {"text": "莖節", "label": 1},
    {"text": "蒴果", "label": 1},
    {"text": "草莖", "label": 1},
    {"text": "葉脈", "label": 1},
    {"text": "花被", "label": 1},
    {"text": "葉腋", "label": 1},
    {"text": "儲藏器官", "label": 1},
    {"text": "花托", "label": 1},
    {"text": "花冠", "label": 1},
    {"text": "花顎", "label": 1},
    {"text": "花粉", "label": 1},
    {"text": "花蕊", "label": 1},
    {"text": "光合作用", "label": 1},
    {"text": "呼吸作用", "label": 1},
    {"text": "裸子植物", "label": 1},
    {"text": "被子植物", "label": 1},
    {"text": "蕨類", "label": 1},
    {"text": "蘚苔", "label": 1},
    {"text": "藻類", "label": 1},
    {"text": "地衣", "label": 1},
    {"text": "種子", "label": 1},
    {"text": "植物真菌", "label": 1},
    {"text": "苔蘚類", "label": 1},
    {"text": "穀類", "label": 1},
    {"text": "蔬菜", "label": 1},
    {"text": "草本植物", "label": 1},
    {"text": "木本植物", "label": 1},
    {"text": "植物", "label": 1},
    {"text": "草", "label": 1},
    {"text": "樹", "label": 1},
    {"text": "根", "label": 1},
    {"text": "莖", "label": 1},
    {"text": "葉", "label": 1},
    {"text": "花", "label": 1},
    {"text": "果實", "label": 1},
    {"text": "種子", "label": 1},
    {"text": "維管束", "label": 1},
    {"text": "木質部", "label": 1},
    {"text": "韌皮部", "label": 1},
    {"text": "葉綠體", "label": 1},
    {"text": "細胞壁", "label": 1},
    {"text": "子房", "label": 1},
    {"text": "胚珠", "label": 1},
    {"text": "胚芽", "label": 1},
    {"text": "花葯", "label": 1},
    {"text": "柱頭", "label": 1},
    {"text": "樹皮", "label": 1},
    {"text": "生長點", "label": 1},
    {"text": "蓼膜", "label": 1},
    {"text": "根毛", "label": 1},
    {"text": "帚狀根", "label": 1},
    {"text": "生長錐", "label": 1},
    {"text": "血管束", "label": 1},
    {"text": "葉柄", "label": 1},
    {"text": "根帽", "label": 1},
    {"text": "絲狀根", "label": 1},
    {"text": "莖節", "label": 1},
    {"text": "蒴果", "label": 1},
    {"text": "草莖", "label": 1},
    {"text": "葉脈", "label": 1},
    {"text": "花被", "label": 1},
    {"text": "葉腋", "label": 1},
    {"text": "儲藏器官", "label": 1},
    {"text": "花托", "label": 1},
    {"text": "花冠", "label": 1},
    {"text": "花顎", "label": 1},
    {"text": "花粉", "label": 1},
    {"text": "花蕊", "label": 1},
    {"text": "光合作用", "label": 1},
    {"text": "呼吸作用", "label": 1},
    {"text": "裸子植物", "label": 1},
    {"text": "被子植物", "label": 1},
    {"text": "蕨類", "label": 1},
    {"text": "蘚苔", "label": 1},
    {"text": "藻類", "label": 1},
    {"text": "地衣", "label": 1},
    {"text": "種子", "label": 1},
    {"text": "植物真菌", "label": 1},
    {"text": "苔蘚類", "label": 1},
    {"text": "穀類", "label": 1},
    {"text": "蔬菜", "label": 1},
    {"text": "草本植物", "label": 1},
    {"text": "木本植物", "label": 1},
    {"text": "植物", "label": 1},
    {"text": "草", "label": 1},
    {"text": "樹", "label": 1},
    {"text": "根", "label": 1},
    {"text": "莖", "label": 1},
    {"text": "葉", "label": 1},
    {"text": "花", "label": 1},
    {"text": "果實", "label": 1},
    {"text": "種子", "label": 1},
    {"text": "維管束", "label": 1},
    {"text": "木質部", "label": 1},
    {"text": "韌皮部", "label": 1},
    {"text": "葉綠體", "label": 1},
    {"text": "細胞壁", "label": 1},
    {"text": "子房", "label": 1},
    {"text": "胚珠", "label": 1},
    {"text": "胚芽", "label": 1},
    {"text": "花葯", "label": 1},
    {"text": "柱頭", "label": 1},
    {"text": "樹皮", "label": 1},
    {"text": "生長點", "label": 1},
    {"text": "蓼膜", "label": 1},
    {"text": "根毛", "label": 1},
    {"text": "帚狀根", "label": 1},
    {"text": "生長錐", "label": 1},
    {"text": "血管束", "label": 1},
    {"text": "葉柄", "label": 1},
    {"text": "根帽", "label": 1},
    {"text": "絲狀根", "label": 1},
    {"text": "莖節", "label": 1},
    {"text": "蒴果", "label": 1},
    {"text": "草莖", "label": 1},
    {"text": "葉脈", "label": 1},
    {"text": "花被", "label": 1},
    {"text": "葉腋", "label": 1},
    {"text": "儲藏器官", "label": 1},
    {"text": "花托", "label": 1},
    {"text": "花冠", "label": 1},
    {"text": "花顎", "label": 1},
    {"text": "花粉", "label": 1},
    {"text": "花蕊", "label": 1},
    {"text": "光合作用", "label": 1},
    {"text": "呼吸作用", "label": 1},
    {"text": "裸子植物", "label": 1},
    {"text": "被子植物", "label": 1},
    {"text": "蕨類", "label": 1},
    {"text": "蘚苔", "label": 1},
    {"text": "藻類", "label": 1},
    {"text": "地衣", "label": 1},
    {"text": "種子", "label": 1},
    {"text": "植物真菌", "label": 1},
    {"text": "苔蘚類", "label": 1},
    {"text": "穀類", "label": 1},
    {"text": "蔬菜", "label": 1},
    {"text": "草本植物", "label": 1},
    {"text": "木本植物", "label": 1},
]

train_data, valid_data = train_test_split(data, test_size=0.2, random_state=42)

train_data_dict = {
    "text": [item["text"] for item in train_data],
    "label": [item["label"] for item in train_data],
}

valid_data_dict = {
    "text": [item["text"] for item in valid_data],
    "label": [item["label"] for item in valid_data],
}

train_dataset = Dataset.from_dict(train_data_dict)
valid_dataset = Dataset.from_dict(valid_data_dict)

dataset = DatasetDict({'train': train_dataset, 'valid': valid_dataset})
print(dataset)

model_name = "bert-base-chinese"
tokenizer = AutoTokenizer.from_pretrained(model_name)

def preprocess_function(examples):
    return tokenizer(examples["text"], truncation=True)
tokenized_data = dataset.map(preprocess_function, batched=True)


data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

accuracy = evaluate.load("accuracy")
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

id2label = {0: "非植物", 1: "植物"}
label2id = {"非植物": 0, "植物": 1}

model = BertForSequenceClassification.from_pretrained(
    model_name, num_labels=2, id2label=id2label, label2id=label2id
)

training_args = TrainingArguments(
    output_dir="intent_model_2",
    learning_rate=2e-4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    # push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data['train'],
    eval_dataset=tokenized_data['valid'],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 134
#     })
#     valid: Dataset({
#         features: ['text', 'label'],
#         num_rows: 34
#     })
# })
# Map:   0%|          | 0/134 [00:00<?, ? examples/s]
# Map:   0%|          | 0/34 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\yehto\Desktop\NLP\意圖分析模型\main 2 copy.ipynb Cell 2 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=205'>206</a> id2label = {0: "非植物", 1: "植物"}
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=206'>207</a> label2id = {"非植物": 0, "植物": 1}
# --> <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=208'>209</a> model = BertForSequenceClassification.from_pretrained(
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=209'>210</a>     model_name, num_labels=2, id2label=id2label, label2id=label2id
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=210'>211</a> )
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=212'>213</a> training_args = TrainingArguments(
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=213'>214</a>     output_dir="intent_model_2",
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=214'>215</a>     learning_rate=2e-4,
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=222'>223</a>     # push_to_hub=True,
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=223'>224</a> )
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=225'>226</a> trainer = Trainer(
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=226'>227</a>     model=model,
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=227'>228</a>     args=training_args,
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=232'>233</a>     compute_metrics=compute_metrics,
#     <a href='vscode-notebook-cell:/c%3A/Users/yehto/Desktop/NLP/%E6%84%8F%E5%9C%96%E5%88%86%E6%9E%90%E6%A8%A1%E5%9E%8B/main%202%20copy.ipynb#W1sZmlsZQ%3D%3D?line=233'>234</a> )
#
# File c:\Users\yehto\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:3307, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3297     if dtype_orig is not None:
#    3298         torch.set_default_dtype(dtype_orig)
#    3300     (
#    3301         model,
#    3302         missing_keys,
#    3303         unexpected_keys,
#    3304         mismatched_keys,
#    3305         offload_index,
#    3306         error_msgs,
# -> 3307     ) = cls._load_pretrained_model(
#    3308         model,
#    3309         state_dict,
#    3310         loaded_state_dict_keys,  # XXX: rename?
#    3311         resolved_archive_file,
#    3312         pretrained_model_name_or_path,
#    3313         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3314         sharded_metadata=sharded_metadata,
#    3315         _fast_init=_fast_init,
#    3316         low_cpu_mem_usage=low_cpu_mem_usage,
#    3317         device_map=device_map,
#    3318         offload_folder=offload_folder,
#    3319         offload_state_dict=offload_state_dict,
#    3320         dtype=torch_dtype,
#    3321         is_quantized=(getattr(model, "quantization_method", None) == QuantizationMethod.BITS_AND_BYTES),
#    3322         keep_in_fp32_modules=keep_in_fp32_modules,
#    3323     )
#    3325 model.is_loaded_in_4bit = load_in_4bit
#    3326 model.is_loaded_in_8bit = load_in_8bit
#
# File c:\Users\yehto\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:3756, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, is_quantized, keep_in_fp32_modules)
#    3752     if "size mismatch" in error_msg:
#    3753         error_msg += (
#    3754             "\n\tYou may consider adding `ignore_mismatched_sizes=True` in the model `from_pretrained` method."
#    3755         )
# -> 3756     raise RuntimeError(f"Error(s) in loading state_dict for {model.__class__.__name__}:\n\t{error_msg}")
#    3758 if is_quantized:
#    3759     unexpected_keys = [elem for elem in unexpected_keys if "SCB" not in elem]
#
# RuntimeError: Error(s) in loading state_dict for BertForSequenceClassification:
# 	size mismatch for classifier.weight: copying a param with shape torch.Size([13, 768]) from checkpoint, the shape in current model is torch.Size([2, 768]).
# 	size mismatch for classifier.bias: copying a param with shape torch.Size([13]) from checkpoint, the shape in current model is torch.Size([2]).
# 	You may consider adding `ignore_mismatched_sizes=True` in the model `from_pretrained` method.

# %%
from transformers import pipeline

text = "你"
classifier = pipeline("text-classification", model="intent_model_2/checkpoint-20")
classifier(text)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [{'label': '植物', 'score': 0.9998258948326111}]

# %%
from datasets import load_dataset

imdb = load_dataset("imdb")
print(imdb)
